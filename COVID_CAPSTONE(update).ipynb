# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\User\\Desktop\\CAPSTONE PROJECT\\covid-19.csv")

# %%
data
# Out:
#           Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 0              1            2000-03-01         2022-01-30                NaN
# 1              2            2019-05-30         2020-05-05         2020-05-05
# 2              3            2019-11-20         2020-10-21         2020-11-21
# 3              4            2019-12-18         2021-12-20         2021-12-20
# 4              5            2020-01-01         2020-04-24         2020-04-24
# ...          ...                   ...                ...                ...
# 1333897  1333898            2022-07-06         2022-07-06         2022-07-06
# 1333898  1333899            2022-07-06         2022-07-06         2022-07-06
# 1333899  1333900            2022-07-06         2022-07-06         2022-07-06
# 1333900  1333901            2022-07-06         2022-07-06         2022-07-06
# 1333901  1333902            2022-07-06         2022-07-06         2022-07-06
#
# ...

# %%
data.head(5)
# Out:
#    Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 0       1            2000-03-01         2022-01-30                NaN
# 1       2            2019-05-30         2020-05-05         2020-05-05
# 2       3            2019-11-20         2020-10-21         2020-11-21
# 3       4            2019-12-18         2021-12-20         2021-12-20
# 4       5            2020-01-01         2020-04-24         2020-04-24
#
#   Specimen_Date Age_Group Client_Gender Case_AcquisitionInfo  Outcome1  \
# 0    2000-03-01       <20        FEMALE  MISSING INFORMATION  Resolved
# 1    2020-05-03       50s        FEMALE                   CC  Resolved
# 2    2019-11-20       20s        FEMALE    NO KNOWN EPI LINK  Resolved
# 3    2019-12-18       30s          MALE  MISSING INFORMATION  Resolved
# 4    2020-04-23       80s          MALE    NO KNOWN EPI LINK  Resolved
#
#   Outbreak_Related  Reporting_PHU_ID  \
# 0              NaN              2243
# 1              NaN              2260
# ...

# %%
data.tail(5)
# Out:
#           Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 1333897  1333898            2022-07-06         2022-07-06         2022-07-06
# 1333898  1333899            2022-07-06         2022-07-06         2022-07-06
# 1333899  1333900            2022-07-06         2022-07-06         2022-07-06
# 1333900  1333901            2022-07-06         2022-07-06         2022-07-06
# 1333901  1333902            2022-07-06         2022-07-06         2022-07-06
#
#         Specimen_Date Age_Group Client_Gender Case_AcquisitionInfo  \
# 1333897    2022-07-06       80s          MALE  MISSING INFORMATION
# 1333898    2022-07-06       80s          MALE  MISSING INFORMATION
# 1333899    2022-07-06       90+        FEMALE  MISSING INFORMATION
# 1333900    2022-07-06       <20        FEMALE  MISSING INFORMATION
# 1333901    2022-07-06       <20          MALE  MISSING INFORMATION
#
#              Outcome1 Outbreak_Related  Reporting_PHU_ID  \
# ...

# %%
data.columns
# Out:
# Index(['Row_ID', 'Accurate_Episode_Date', 'Case_Reported_Date',
#        'Test_Reported_Date', 'Specimen_Date', 'Age_Group', 'Client_Gender',
#        'Case_AcquisitionInfo', 'Outcome1', 'Outbreak_Related',
#        'Reporting_PHU_ID', 'Reporting_PHU', 'Reporting_PHU_Address',
#        'Reporting_PHU_City', 'Reporting_PHU_Postal_Code',
#        'Reporting_PHU_Website', 'Reporting_PHU_Latitude',
#        'Reporting_PHU_Longitude'],
#       dtype='object')

# %%
data.shape
# Out:
# (1333902, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1333902 entries, 0 to 1333901
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Row_ID                     1333902 non-null  int64
#  1   Accurate_Episode_Date      1333902 non-null  object
#  2   Case_Reported_Date         1333902 non-null  object
#  3   Test_Reported_Date         1300491 non-null  object
#  4   Specimen_Date              1325658 non-null  object
#  5   Age_Group                  1333902 non-null  object
#  6   Client_Gender              1333902 non-null  object
#  7   Case_AcquisitionInfo       1333902 non-null  object
#  8   Outcome1                   1333902 non-null  object
#  9   Outbreak_Related           186046 non-null   object
#  10  Reporting_PHU_ID           1333902 non-null  int64
#  11  Reporting_PHU              1333902 non-null  object
#  12  Reporting_PHU_Address      1333902 non-null  object
# ...

# %%
data.dtypes
# Out:
# Row_ID                         int64
# Accurate_Episode_Date         object
# Case_Reported_Date            object
# Test_Reported_Date            object
# Specimen_Date                 object
# Age_Group                     object
# Client_Gender                 object
# Case_AcquisitionInfo          object
# Outcome1                      object
# Outbreak_Related              object
# Reporting_PHU_ID               int64
# Reporting_PHU                 object
# Reporting_PHU_Address         object
# Reporting_PHU_City            object
# Reporting_PHU_Postal_Code     object
# Reporting_PHU_Website         object
# Reporting_PHU_Latitude       float64
# Reporting_PHU_Longitude      float64
# dtype: object

# %%
data['Accurate_Episode_Date'] = pd.to_datetime(data['Accurate_Episode_Date'])
data['Case_Reported_Date'] = pd.to_datetime(data['Case_Reported_Date'])
data['Test_Reported_Date'] = pd.to_datetime(data['Test_Reported_Date'])
data['Specimen_Date'] = pd.to_datetime(data['Specimen_Date'])

# %%
data.dtypes
# Out:
# Row_ID                                int64
# Accurate_Episode_Date        datetime64[ns]
# Case_Reported_Date           datetime64[ns]
# Test_Reported_Date           datetime64[ns]
# Specimen_Date                datetime64[ns]
# Age_Group                            object
# Client_Gender                        object
# Case_AcquisitionInfo                 object
# Outcome1                             object
# Outbreak_Related                     object
# Reporting_PHU_ID                      int64
# Reporting_PHU                        object
# Reporting_PHU_Address                object
# Reporting_PHU_City                   object
# Reporting_PHU_Postal_Code            object
# Reporting_PHU_Website                object
# Reporting_PHU_Latitude              float64
# Reporting_PHU_Longitude             float64
# dtype: object

# %%
data.Age_Group = data.Age_Group.astype("category")
data.Client_Gender = data.Client_Gender.astype("category")
data.Case_AcquisitionInfo = data.Case_AcquisitionInfo.astype("category")
data.Outcome1 = data.Outcome1.astype("category")

data.Reporting_PHU = data.Reporting_PHU.astype("category")
data.Reporting_PHU_Address = data.Reporting_PHU_Address.astype("category")
data.Reporting_PHU_City = data.Reporting_PHU_City.astype("category")

data.Reporting_PHU_Postal_Code = data.Reporting_PHU_Postal_Code.astype("category")
data.Reporting_PHU_Website = data.Reporting_PHU_Website.astype("category")

# %%
data.dtypes
# Out:
# Row_ID                                int64
# Accurate_Episode_Date        datetime64[ns]
# Case_Reported_Date           datetime64[ns]
# Test_Reported_Date           datetime64[ns]
# Specimen_Date                datetime64[ns]
# Age_Group                          category
# Client_Gender                      category
# Case_AcquisitionInfo               category
# Outcome1                           category
# Outbreak_Related                     object
# Reporting_PHU_ID                      int64
# Reporting_PHU                      category
# Reporting_PHU_Address              category
# Reporting_PHU_City                 category
# Reporting_PHU_Postal_Code          category
# Reporting_PHU_Website              category
# Reporting_PHU_Latitude              float64
# Reporting_PHU_Longitude             float64
# dtype: object

# %%
data = data.drop_duplicates()
data.shape
# Out:
# (1333902, 18)

# %%
subset=['Row_ID', 'Accurate_Episode_Date', 'Case_Reported_Date',
       'Test_Reported_Date', 'Specimen_Date', 'Age_Group', 'Client_Gender',
       'Case_AcquisitionInfo', 'Outcome1', 'Reporting_PHU_ID', 'Reporting_PHU', 'Reporting_PHU_Address',
       'Reporting_PHU_City', 'Reporting_PHU_Postal_Code',
       'Reporting_PHU_Website', 'Reporting_PHU_Latitude',
       'Reporting_PHU_Longitude']

# %%
data.shape
# Out:
# (1333902, 18)

# %%
data.isnull().sum()
# Out:
# Row_ID                             0
# Accurate_Episode_Date              0
# Case_Reported_Date                 0
# Test_Reported_Date             33411
# Specimen_Date                   8244
# Age_Group                          0
# Client_Gender                      0
# Case_AcquisitionInfo               0
# Outcome1                           0
# Outbreak_Related             1147856
# Reporting_PHU_ID                   0
# Reporting_PHU                      0
# Reporting_PHU_Address              0
# Reporting_PHU_City                 0
# Reporting_PHU_Postal_Code          0
# Reporting_PHU_Website              0
# Reporting_PHU_Latitude             0
# Reporting_PHU_Longitude            0
# dtype: int64

# %%
del data['Outbreak_Related']
data
# Out:
#           Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 0              1            2000-03-01         2022-01-30                NaT
# 1              2            2019-05-30         2020-05-05         2020-05-05
# 2              3            2019-11-20         2020-10-21         2020-11-21
# 3              4            2019-12-18         2021-12-20         2021-12-20
# 4              5            2020-01-01         2020-04-24         2020-04-24
# ...          ...                   ...                ...                ...
# 1333897  1333898            2022-07-06         2022-07-06         2022-07-06
# 1333898  1333899            2022-07-06         2022-07-06         2022-07-06
# 1333899  1333900            2022-07-06         2022-07-06         2022-07-06
# 1333900  1333901            2022-07-06         2022-07-06         2022-07-06
# 1333901  1333902            2022-07-06         2022-07-06         2022-07-06
#
# ...

# %%
#create dataframe and remove null values by columns
data['Test_Reported_Date'] = data['Test_Reported_Date'].replace('-','NaT')
data = data.dropna(axis=0, subset=['Test_Reported_Date'])

# %%
data.loc[data["Test_Reported_Date"].isnull(),"Test_Reported_Date"]
# Out:
# Series([], Name: Test_Reported_Date, dtype: datetime64[ns])

# %%
data
# Out:
#           Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 1              2            2019-05-30         2020-05-05         2020-05-05
# 2              3            2019-11-20         2020-10-21         2020-11-21
# 3              4            2019-12-18         2021-12-20         2021-12-20
# 4              5            2020-01-01         2020-04-24         2020-04-24
# 5              6            2020-01-01         2020-05-17         2020-05-17
# ...          ...                   ...                ...                ...
# 1333897  1333898            2022-07-06         2022-07-06         2022-07-06
# 1333898  1333899            2022-07-06         2022-07-06         2022-07-06
# 1333899  1333900            2022-07-06         2022-07-06         2022-07-06
# 1333900  1333901            2022-07-06         2022-07-06         2022-07-06
# 1333901  1333902            2022-07-06         2022-07-06         2022-07-06
#
# ...

# %%
data.loc[data["Specimen_Date"].isnull(),"Specimen_Date"]
# Out:
# 2254     NaT
# 2931     NaT
# 3326     NaT
# 4162     NaT
# 4186     NaT
#           ..
# 356358   NaT
# 382441   NaT
# 387303   NaT
# 389415   NaT
# 398610   NaT
# Name: Specimen_Date, Length: 165, dtype: datetime64[ns]

# %%
data['Specimen_Date'] = data['Specimen_Date'].replace('-','NaT')
data = data.dropna(axis=0, subset=['Specimen_Date'])
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_22960/1439514058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Specimen_Date'] = data['Specimen_Date'].replace('-','NaT')

# %%
data.loc[data["Specimen_Date"].isnull(),"Specimen_Date"]
# Out:
# Series([], Name: Specimen_Date, dtype: datetime64[ns])

# %%
data.isnull().sum()
# Out:
# Row_ID                       0
# Accurate_Episode_Date        0
# Case_Reported_Date           0
# Test_Reported_Date           0
# Specimen_Date                0
# Age_Group                    0
# Client_Gender                0
# Case_AcquisitionInfo         0
# Outcome1                     0
# Reporting_PHU_ID             0
# Reporting_PHU                0
# Reporting_PHU_Address        0
# Reporting_PHU_City           0
# Reporting_PHU_Postal_Code    0
# Reporting_PHU_Website        0
# Reporting_PHU_Latitude       0
# Reporting_PHU_Longitude      0
# dtype: int64

# %%
countmale = data.loc[data["Client_Gender"]== "MALE",].shape[0]
countfemale = data.loc[data["Client_Gender"]== "FEMALE",].shape[0]
slices =[countmale, countfemale]
labels=["MALE","FEMALE"]
print("Client_Gender:",countmale)
print("Client_Gender:",countfemale)
explode= [0.2,0]
plt.pie(slices, labels = labels, explode= explode, startangle= -40, autopct = '%1.0f%%', wedgeprops={'edgecolor':'blue'})
plt.axis("equal")
plt.title("Distribution of Client_Gender")
plt.legend(labels, loc='upper right', bbox_to_anchor=(-0.1, 1.),
           fontsize=11)
plt.show()
# Out:
# Client_Gender: 601463
# Client_Gender: 692571

# %%
CC = data.loc[data["Case_AcquisitionInfo"]== "CC",].shape[0]
MISSING_INFORMATION = data.loc[data["Case_AcquisitionInfo"]== "MISSING INFORMATION",].shape[0]
OB = data.loc[data["Case_AcquisitionInfo"]== "OB",].shape[0]
TRAVEL = data.loc[data["Case_AcquisitionInfo"]== "TRAVEL",].shape[0]
UNSPECIFIED_EPI_LINK = data.loc[data["Case_AcquisitionInfo"]== "UNSPECIFIED EPI LINK",].shape[0]
NO_KNOWN_EPI_LINK = data.loc[data["Case_AcquisitionInfo"]== "NO KNOWN EPI LINK",].shape[0]

slices =[ CC, MISSING_INFORMATION, OB, TRAVEL, UNSPECIFIED_EPI_LINK, NO_KNOWN_EPI_LINK]

labels=[ "CC","MISSING INFORMATION", "OB", "TRAVEL", "UNSPECIFIED EPI LINK", "NO KNOWN EPI LINK"]

print("CC:", CC)
print("MISSING_INFORMATION:", MISSING_INFORMATION)
print("OB:", OB)
print("TRAVEL:", TRAVEL)
print("UNSPECIFIED_EPI_LINK:", UNSPECIFIED_EPI_LINK)
print("NO_KNOWN_EPI_LINK:", NO_KNOWN_EPI_LINK)

explode= [0.1, 0, 0 ,0.1,0,0]
plt.pie(slices, labels = labels, explode= explode, startangle= -80, autopct = '%1.1f%%', wedgeprops={'edgecolor':'blue'})
plt.axis("equal")
plt.title("Distribution of Case_Information", fontsize=30)
plt.legend(labels, loc='upper right', bbox_to_anchor=(-0.1, 1.),fontsize=11)
plt.show()
# Out:
# CC: 372315
# MISSING_INFORMATION: 479376
# OB: 166105
# TRAVEL: 21973
# UNSPECIFIED_EPI_LINK: 27
# NO_KNOWN_EPI_LINK: 260530

# %%
Not_Resolved = data.loc[data["Outcome1"]== "Not Resolved",].shape[0]
Resolved = data.loc[data["Outcome1"]== "Resolved",].shape[0]

slices =[Not_Resolved, Resolved]
labels=["Not Resolved","Resolved"]

print("Not_Resolved:",Not_Resolved)
print("Resolved:",Resolved)

explode= [0.1,0.1]

plt.pie(slices, labels = labels, explode= explode, startangle= -40, autopct = '%1.0f%%', wedgeprops={'edgecolor':'black'})
plt.axis("equal")

plt.title("Number Of Recoveries",loc='right', fontsize=40)
plt.legend(labels, loc='upper right', bbox_to_anchor=(-0.1, 1.),
           fontsize=11)
plt.show()
# Out:
# Not_Resolved: 10451
# Resolved: 1276805

# %%
data.dtypes
# Out:
# Row_ID                                int64
# Accurate_Episode_Date        datetime64[ns]
# Case_Reported_Date           datetime64[ns]
# Test_Reported_Date           datetime64[ns]
# Specimen_Date                datetime64[ns]
# Age_Group                          category
# Client_Gender                      category
# Case_AcquisitionInfo               category
# Outcome1                           category
# Reporting_PHU_ID                      int64
# Reporting_PHU                      category
# Reporting_PHU_Address              category
# Reporting_PHU_City                 category
# Reporting_PHU_Postal_Code          category
# Reporting_PHU_Website              category
# Reporting_PHU_Latitude              float64
# Reporting_PHU_Longitude             float64
# dtype: object

# %%
data
# Out:
#           Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 1              2            2019-05-30         2020-05-05         2020-05-05
# 2              3            2019-11-20         2020-10-21         2020-11-21
# 3              4            2019-12-18         2021-12-20         2021-12-20
# 4              5            2020-01-01         2020-04-24         2020-04-24
# 5              6            2020-01-01         2020-05-17         2020-05-17
# ...          ...                   ...                ...                ...
# 1333897  1333898            2022-07-06         2022-07-06         2022-07-06
# 1333898  1333899            2022-07-06         2022-07-06         2022-07-06
# 1333899  1333900            2022-07-06         2022-07-06         2022-07-06
# 1333900  1333901            2022-07-06         2022-07-06         2022-07-06
# 1333901  1333902            2022-07-06         2022-07-06         2022-07-06
#
# ...

# %%
Algoma = data.loc[data["Reporting_PHU"]== "Algoma Public Health Unit",].shape[0]
Brant = data.loc[data["Reporting_PHU"]== "Brant County Health Unit",].shape[0]
Chatham = data.loc[data["Reporting_PHU"]== "Chatham-Kent Health Unit",].shape[0]
Toronto = data.loc[data["Reporting_PHU"]== "Toronto Public Health",].shape[0]
Ottawa = data.loc[data["Reporting_PHU"]== "Ottawa Public Health",].shape[0]
Eastern = data.loc[data["Reporting_PHU"]== "Eastern Ontario Health Unit",].shape[0]



print("Algoma:",Algoma)
print("Brant:",Brant)
print("Chatham:",Chatham)
print("Toronto:",Toronto)
print("Ottawa:",Ottawa)
print("Eastern:",Eastern)
# Out:
# Algoma: 7832
# Brant: 11673
# Chatham: 8679
# Toronto: 317046
# Ottawa: 75252
# Eastern: 15763

# %%
Reported_Case_PHU1 = data.loc[data["Reporting_PHU"]== "Peel Public Health",].shape[0]   #mississuaga
Reported_Case_PHU2 = data.loc[data["Reporting_PHU"]== "Brant County Health Unit",].shape[0]  #Brantford
Reported_Case_PHU3 = data.loc[data["Reporting_PHU"]== "Chatham-Kent Health Unit",].shape[0]  #Chatham
Reported_Case_PHU4 = data.loc[data["Reporting_PHU"]== "Toronto Public Health",].shape[0]   #toronto
Reported_Case_PHU5 = data.loc[data["Reporting_PHU"]== "Hamilton Public Health Services",].shape[0]   #hamilton

slices = [Reported_Case_PHU1, Reported_Case_PHU2, Reported_Case_PHU3, Reported_Case_PHU4, Reported_Case_PHU5]

labels=["Peel Public Health","Brant County Health Unit","Chatham-Kent Health Unit","Toronto Public Health", "Hamilton Public Health Services"]

print("Peel Public Health :", Reported_Case_PHU1)
print("Brant County Health Unit :", Reported_Case_PHU2)
print("Chatham-Kent Health Unit :", Reported_Case_PHU3)
print("Toronto Public Health :", Reported_Case_PHU4)
print("Hamilton Public Health Services :", Reported_Case_PHU5)

explode= [0.1,0.5,0.0,0.0,0]

plt.pie(slices, labels = labels, explode= explode, shadow= False , startangle= -30, autopct = '%1.1f%%', wedgeprops={'edgecolor':'black'})
plt.axis("equal")
plt.tight_layout ()
plt.title("Number Of Case Reported At PHU", fontsize=40)
plt.legend(labels, loc='upper right', bbox_to_anchor=(-0.1, 1.0),
           fontsize=11)
plt.show()
# Out:
# Peel Public Health : 186642
# Brant County Health Unit : 11673
# Chatham-Kent Health Unit : 8679
# Toronto Public Health : 317046
# Hamilton Public Health Services : 59563

# %%
data["Reporting_PHU"].unique()
# Out:
# ['Simcoe Muskoka District Health Unit', 'Southwestern Public Health', 'York Region Public Health Services', 'Haldimand-Norfolk Health Unit', 'Region of Waterloo, Public Health', ..., 'Algoma Public Health Unit', 'North Bay Parry Sound District Health Unit', 'Timiskaming Health Unit', 'Renfrew County and District Health Unit', 'Northwestern Health Unit']
# Length: 34
# Categories (34, object): ['Algoma Public Health Unit', 'Brant County Health Unit', 'Chatham-Kent Health Unit', 'Durham Region Health Department', ..., 'Toronto Public Health', 'Wellington-Dufferin-Guelph Public Health', 'Windsor-Essex County Health Unit', 'York Region Public Health Services']

# %%
data["Reporting_PHU_Address"].unique()
# Out:
# ['15 Sperling Drive', '1230 Talbot Street', '17250 Yonge Street', '12 Gilbertson Drive', '99 Regina Street South', ..., '294 Willow Avenue', '345 Oak Street West', '247 Whitewood Avenue, Unit 43', '7 International Drive', '210 First Street North']
# Length: 34
# Categories (34, object): ['100 Constellation Drive', '1000 Pitt Street', '1005 Ouellette Avenue', '101 17th Street East', ..., '7 International Drive', '7120 Hurontario Street', '99 Regina Street South', '999 Balmoral Street']

# %%
Reported_Adress_PHU1 = data.loc[data["Reporting_PHU_Address"]== "1230 Talbot Street",].shape[0]
Reported_Adress_PHU2 = data.loc[data["Reporting_PHU_Address"]== "12 Gilbertson Drive",].shape[0]
Reported_Adress_PHU3 = data.loc[data["Reporting_PHU_Address"]== "99 Regina Street South",].shape[0]
Reported_Adress_PHU4 = data.loc[data["Reporting_PHU_Address"]== "277 Victoria Street, 5th Floor",].shape[0]




slices = [Reported_Adress_PHU1,Reported_Adress_PHU2,Reported_Adress_PHU3,Reported_Adress_PHU4]
labels=["1230 Talbot Street","12 Gilbertson Drive","99 Regina Street South","277 Victoria Street, 5th Floor"]

print("Reporting_PHU_Address1 :", Reported_Adress_PHU1)
print("Reporting_PHU_Address2 :", Reported_Adress_PHU2)
print("Reporting_PHU_Address3 :", Reported_Adress_PHU3)
print("Reporting_PHU_Address4 :", Reported_Adress_PHU4)

explode= [0.1,0,0,0]

plt.pie(slices, labels = labels, explode= explode, shadow= True, startangle= -30, autopct = '%1.1f%%', wedgeprops={'edgecolor':'black'})
plt.axis("equal")
plt.tight_layout ()
plt.title("Number Of Case Reported At PHU", fontsize=30)
plt.legend(labels, loc='upper right', bbox_to_anchor=(-0.1, 1.),
           fontsize=11)
plt.show()
# Out:
# Reporting_PHU_Address1 : 13811
# Reporting_PHU_Address2 : 8465
# Reporting_PHU_Address3 : 46703
# Reporting_PHU_Address4 : 317046

# %%
City_PHU1 = data.loc[data["Reporting_PHU_City"]== "St. Thomas",].shape[0]
City_PHU2 = data.loc[data["Reporting_PHU_City"]== "Simcoe",].shape[0]
City_PHU3 = data.loc[data["Reporting_PHU_City"]== "Waterloo",].shape[0]
City_PHU4 = data.loc[data["Reporting_PHU_City"]== "Toronto",].shape[0]
City_PHU5 = data.loc[data["Reporting_PHU_City"]== "Mississauga",].shape[0]


slices = [City_PHU1,City_PHU2,City_PHU3, City_PHU4, City_PHU5]
labels=["St. Thomas","Simcoe","Waterloo","Toronto", "Mississauga"]

print("St. Thomas: ", City_PHU1)
print("Simcoe: ", City_PHU2)
print("Waterloo: ", City_PHU3)
print("Toronto: ", City_PHU4)
print("Mississauga: ", City_PHU5)

explode= [0.1,0,0,0,0]

plt.pie(slices, labels = labels, explode= explode, shadow= True, startangle= -30, autopct = '%1.1f%%', wedgeprops={'edgecolor':'black'})
plt.axis("equal")
plt.tight_layout ()
plt.title("Number Of Case Reported At PHU", fontsize=30)
plt.legend(labels, loc='upper right', bbox_to_anchor=(-0.1, 1.),
           fontsize=11)
plt.show()
# Out:
# St. Thomas:  13811
# Simcoe:  8465
# Waterloo:  46703
# Toronto:  317046
# Mississauga:  186642

# %%
data.Reporting_PHU_City.value_counts(sort=True).plot.bar(figsize = (15,3))
# Out:
# <AxesSubplot:>

# %%
data.Age_Group.value_counts(sort=True).plot.bar(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
ff_DF = data[(data['Outcome1'] == 'Fatal') & (data['Client_Gender'] == 'FEMALE')]
fm_DF = data[(data['Outcome1'] == 'Fatal') & (data['Client_Gender'] == 'MALE')]
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
ff_DF.Age_Group.value_counts(sort=False).plot.bar(ax=axes[0], title='Fatal age group - Female')
fm_DF.Age_Group.value_counts(sort=False).plot.bar(ax=axes[1], title='Fatal age group - Male')
# Out:
# <AxesSubplot:title={'center':'Fatal age group - Male'}>

# %%
ff_DF = data[(data['Reporting_PHU_City'] == 'Toronto') & (data['Client_Gender'] == 'MALE')]
fm_DF = data[(data['Reporting_PHU_City'] == 'Waterloo') & (data['Client_Gender'] == 'MALE')]
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
ff_DF.Reporting_PHU_City.value_counts(sort=False).plot.bar(ax=axes[0], title='toronto')
fm_DF.Reporting_PHU_City.value_counts(sort=False).plot.bar(ax=axes[1], title='waterloo')
# Out:
# <AxesSubplot:title={'center':'waterloo'}>

# %%
data.corr()
# Out:
#                            Row_ID  Reporting_PHU_ID  Reporting_PHU_Latitude  \
# Row_ID                   1.000000         -0.076828                0.116262
# Reporting_PHU_ID        -0.076828          1.000000               -0.171384
# Reporting_PHU_Latitude   0.116262         -0.171384                1.000000
# Reporting_PHU_Longitude -0.041674          0.025954               -0.109121
#
#                          Reporting_PHU_Longitude
# Row_ID                                 -0.041674
# Reporting_PHU_ID                        0.025954
# Reporting_PHU_Latitude                 -0.109121
# Reporting_PHU_Longitude                 1.000000

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
corr1 = data.corr(method='spearman').round(2)
corr1
# Out:
#                          Row_ID  Reporting_PHU_ID  Reporting_PHU_Latitude  \
# Row_ID                     1.00             -0.11                    0.07
# Reporting_PHU_ID          -0.11              1.00                    0.12
# Reporting_PHU_Latitude     0.07              0.12                    1.00
# Reporting_PHU_Longitude   -0.03              0.11                    0.56
#
#                          Reporting_PHU_Longitude
# Row_ID                                     -0.03
# Reporting_PHU_ID                            0.11
# Reporting_PHU_Latitude                      0.56
# Reporting_PHU_Longitude                     1.00

# %%
from statsmodels.tsa.arima_model import ARIMA 
from pandas.plotting import autocorrelation_plot

# %%
data.plot()
plt.show()
print(data.head())
# Out:
#    Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 1       2            2019-05-30         2020-05-05         2020-05-05
# 2       3            2019-11-20         2020-10-21         2020-11-21
# 3       4            2019-12-18         2021-12-20         2021-12-20
# 4       5            2020-01-01         2020-04-24         2020-04-24
# 5       6            2020-01-01         2020-05-17         2020-05-17
#
#   Specimen_Date Age_Group Client_Gender Case_AcquisitionInfo  Outcome1  \
# 1    2020-05-03       50s        FEMALE                   CC  Resolved
# 2    2019-11-20       20s        FEMALE    NO KNOWN EPI LINK  Resolved
# 3    2019-12-18       30s          MALE  MISSING INFORMATION  Resolved
# 4    2020-04-23       80s          MALE    NO KNOWN EPI LINK  Resolved
# 5    2020-05-15       50s          MALE                   CC  Resolved
#
#    Reporting_PHU_ID                        Reporting_PHU  \
# ...

# %%
def plot_data(data, x, y, title="", xlabel='Accurate_Episode_Date', ylabel='Case_Reported_Date', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='grey')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_data(data, x=data.Accurate_Episode_Date, y=data.Case_Reported_Date, title='Covid Case Reported in Canada from 2019 to 2022.')

# %%
from pandas.plotting import autocorrelation_plot
def parser(x):
    return datetime.strptime('202'+x , '%y, %m')
 
autocorrelation_plot(data)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22960/613302557.py in <module>
#       3     return datetime.strptime('202'+x , '%y, %m')
#       4
# ----> 5 autocorrelation_plot(data)
#       6 pyplot.show()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_misc.py in autocorrelation_plot(series, ax, **kwargs)
#     483     """
#     484     plot_backend = _get_plot_backend("matplotlib")
# --> 485     return plot_backend.autocorrelation_plot(series=series, ax=ax, **kwargs)
#     486
#     487
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py in autocorrelation_plot(series, ax, **kwds)
#     452         ax.set_xlim(1, n)
#     453         ax.set_ylim(-1.0, 1.0)
# --> 454     mean = np.mean(data)
#     455     c0 = np.sum((data - mean) ** 2) / n
#     456
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ...

# %%
data.dtypes
# Out:
# Row_ID                                int64
# Accurate_Episode_Date        datetime64[ns]
# Case_Reported_Date           datetime64[ns]
# Test_Reported_Date           datetime64[ns]
# Specimen_Date                datetime64[ns]
# Age_Group                          category
# Client_Gender                      category
# Case_AcquisitionInfo               category
# Outcome1                           category
# Reporting_PHU_ID                      int64
# Reporting_PHU                      category
# Reporting_PHU_Address              category
# Reporting_PHU_City                 category
# Reporting_PHU_Postal_Code          category
# Reporting_PHU_Website              category
# Reporting_PHU_Latitude              float64
# Reporting_PHU_Longitude             float64
# dtype: object

# %%
data = pd.get_dummies(data, columns=['Age_Group', 'Client_Gender', 'Case_AcquisitionInfo','Outcome1',
                                    'Reporting_PHU','Reporting_PHU_Address','Reporting_PHU_City',
                                    'Reporting_PHU_Postal_Code','Reporting_PHU_Website'], drop_first = True)

# %%
data
# Out:
#           Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 1              2            2019-05-30         2020-05-05         2020-05-05
# 2              3            2019-11-20         2020-10-21         2020-11-21
# 3              4            2019-12-18         2021-12-20         2021-12-20
# 4              5            2020-01-01         2020-04-24         2020-04-24
# 5              6            2020-01-01         2020-05-17         2020-05-17
# ...          ...                   ...                ...                ...
# 1333897  1333898            2022-07-06         2022-07-06         2022-07-06
# 1333898  1333899            2022-07-06         2022-07-06         2022-07-06
# 1333899  1333900            2022-07-06         2022-07-06         2022-07-06
# 1333900  1333901            2022-07-06         2022-07-06         2022-07-06
# 1333901  1333902            2022-07-06         2022-07-06         2022-07-06
#
# ...
